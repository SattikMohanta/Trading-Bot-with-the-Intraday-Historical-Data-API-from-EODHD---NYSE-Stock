# %% [markdown]
# There are a lot of official and unofficial data sources on the web providing COVID-19 related data. One of the most widely used dataset today is the one provided by the
# _**John Hopkins University’s Center for Systems Science and Engineering (JHU CSSE)**_
#
# #### Official github Link: [Novel Coronavirus (COVID-19) Cases, provided by JHU CSSE](https://github.com/CSSEGISandData/COVID-19)
#
# <img src="https://avatars.githubusercontent.com/u/60674295?v=4.gif" alt="John Hopkins University’s Center for Systems Science and Engineering" title="JHU_CSSE"/>
#
# #### [Consolidated Link CSSEGIS](https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series)
#
# #### Country wise most updated source [Our World in Data](https://ourworldindata.org/coronavirus-testing#source-information-country-by-country)
# #### [Our World in Data Latest](https://github.com/owid/covid-19-data/blob/master/public/data/latest/owid-covid-latest.csv)
#
# <img src="https://ourworldindata.org/default-thumbnail.jpg" alt="Our World in Data" title="OVID"/>
#
#
# #### _**Alternative sources for ref**_ (SARS COV2 variant dataset)
# <img src="https://www.ecdc.europa.eu/profiles/custom/ecdc/themes/anthrax/images/logo-ecdc.png" alt="European Centre for Disease Prevention and Control" title="ECDC.EUROPE" />
#
# * #### [European Centre for Disease Prevention and Control](https://www.ecdc.europa.eu/en/publications-data/data-virus-variants-covid-19-eueea)
#
# The data contains the following 3 files:
#
#  * #### time_series_19-covid-confirmed_global.csv
#  * #### time_series_19-covid-deaths_global.csv
#  * #### time_series_19-covid-recovered_global.csv
#  * #### cases_country.csv
# [OWID raw daily updated source](https://ourworldindata.org/coronavirus-testing#source-information-country-by-country) ||
# [OWID github source consolidated](https://github.com/owid/covid-19-data/blob/master/public/data/latest/owid-covid-latest.csv)

# %% [markdown]
# ### API references
# * #### [Pandas](https://pandas.pydata.org/docs/reference/index.html#api)
#
# * #### [Matplotlib](https://matplotlib.org/stable/api/index)
#
# * #### [Scikit-learn](https://scikit-learn.org/stable/modules/classes.html)
#
# * #### [Numpy](https://numpy.org/doc/stable/reference/index.html)
#
# * #### [Seaborn](https://seaborn.pydata.org/api.html)
#
# * #### [Plotly](https://plotly.com/python/)
#
# * #### [Pycaret](https://pycaret.gitbook.io/docs/)
#
# * #### [Bokeh guide](https://docs.bokeh.org/en/latest/#:~:text=Bokeh%20is%20a%20Python%20library,without%20writing%20any%20JavaScript%20yourself.) || [Bokeh](https://docs.bokeh.org/en/latest/docs/reference.html)
#
# * #### [Others](https://bigdata-madesimple.com/top-20-python-libraries-for-data-science/) || [py packages](https://pypi.org/)

# %% [markdown]
# #### Get the raw url of the file from github (https://raw.githubusercontent.com/username/folder/example.xyz)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Update the Dataset from Git Repository
#
# If your python project relies on the data from the git repository. After you clone the repository and get the dataset to your local machine, you might have to periodically do git fetch or pull to keep your dataset up-to-date. In this case, you may use the GitPython module to automatically update your project dataset automatically. To use this module, you have to install it first, which you can easily use pip to do so.
# pip install gitpython
# If you run to an error, you may check this full GitPython document to check the requirements you might not have of your os environment. After you have the module installed, you can just easily follow these codes to automatically do the git pull every time you run your code.
#
#
#
# ###### import git
#
# ###### repo = git.Repo('<https://covid.ourworldindata.org/data/owid-covid-data.csv')
#
# ###### repo.remotes.origin.pull()

# %%
import git
g = git.Git('https://github.com/owid/covid-19-data/blob/master/public/data/')
g.pull('covid-19-data/public/data/','master')
# Out:
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# <ipython-input-18-5a1e9fd89a55> in <module>
#       1 import git
#       2 g = git.Git('https://github.com/owid/covid-19-data/blob/master/public/data/')
# ----> 3 g.pull('covid-19-data/public/data/','master')
#
# ~\anaconda3\lib\site-packages\git\cmd.py in <lambda>(*args, **kwargs)
#     636         if name[0] == '_':
#     637             return LazyMixin.__getattr__(self, name)
# --> 638         return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#     639
#     640     def set_persistent_git_options(self, **kwargs: Any) -> None:
#
# ~\anaconda3\lib\site-packages\git\cmd.py in _call_process(self, method, *args, **kwargs)
#    1181         call.extend(args_list)
#    1182
# -> 1183         return self.execute(call, **exec_kwargs)
#    1184
# ...

# %% [markdown]
# #### Purpose of %matplotlib inline
# ##### [Source](http://stackoverflow.com/questions/43027980/ddg#43028034)
# **%matplotlib is a magic function in IPython**
#
# IPython has a set of predefined ‘magic functions’ that you can call with a command line style syntax. There are two kinds of magics, line-oriented and cell-oriented. Line magics are prefixed with the % character and work much like OS command-line calls: they get as an argument the rest of the line, where arguments are passed without parentheses or quotes. Lines magics can return results and can be used in the right hand side of an assignment. Cell magics are prefixed with a double %%, and they are functions that get as an argument not only the rest of the line, but also the lines below it in a separate argument.

# %% [markdown]
# ###### import urllib.request ### request library for auto updating raw sets
# ###### url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'
# [raw source](https://covid.ourworldindata.org/data/owid-covid-data.csv)
# ###### output = '<Your output filename/location>'
# ###### urllib.request.urlretrieve(url, output)

# %% [markdown]
# ## Following first 3 cases are -
# * #### Confirmed
# * #### Deaths
# * #### Recovered
#
# ### [4th one is an aggregate of all cases]()
# * #### Country cases

# %%
confirmed_case_link = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
death_case_link = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
recovered_case_link = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"

# %%
confirmed_df = pd.read_csv(confirmed_case_link)
print(confirmed_df.shape)
death_df = pd.read_csv(death_case_link)
print(death_df.shape)
recovered_df = pd.read_csv(recovered_case_link)
print(recovered_df.shape)
# Out:
# (280, 739)
# (280, 739)
# (265, 739)

# %%
country_df = pd.read_csv ("https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-data.csv")
# %%debug
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-bfa192eb9d36> in <module>
# ----> 1 country_df = pd.read_csv ("https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-data.csv")
#       2 get_ipython().run_line_magic('%debug', '')
#
# ...

# %%
confirmed_df.head()
confirmed_df.dropna(axis='columns')

# %%
recovered_df.head()
recovered_df.dropna(axis='columns')

# %%
death_df.head()
death_df.dropna(axis='columns')

# %%
confirmed_df.columns
confirmed_df[confirmed_df['Country/Region']=='India']

# %%
confirmed_df[confirmed_df['Country/Region']=='Australia']

# %%
death_df[death_df['Country/Region']=='Australia']

# %%
#confirmed_df["Country/Region"].unique()
confirmed_df["Country/Region"].nunique()

# %% [markdown]
# ### Imputing Data
# #### To drop zeros/null values from the dataframe

# %%
confirmed_df=confirmed_df.replace(np.nan, '',regex=True)
recovered_df=recovered_df.replace(np.nan, '',regex=True)
death_df=death_df.replace(np.nan, '',regex=True)
country_df=country_df.replace(np.nan, '',regex=True)

# %% [markdown]
# #### Viewing the columns in the DataFrame (Timeseries)

# %%
country_df.columns
# country_df.head()
country_df.drop(['UID','iso2','iso3','FIPS','Admin2','Province_State'], axis =1)

# %% [markdown]
# ## Exploratory Data Analysis
# ### Count cases - Global Summary

# %%
global_data = country_df.copy().drop(['Lat','Long_','Country_Region'],axis =1)
global_summary = pd.DataFrame(global_data.sum()).transpose()
global_summary

# %%
confirmed_ts = confirmed_df.copy().drop(['Lat','Province/State'],axis =1)
confirmed_ts_summary =confirmed_ts.sum()
confirmed_ts_summary
