# %% [markdown]
# ## Alternatively - Launch JupyterLab with: python -m jupyter lab
# ## Then render a mitosheet following the instructions here: https://docs.trymito.io/how-to/creating-a-mitosheet
# ### https://www.youtube.com/watch?time_continue=2&v=-snyx_pjfd0&feature=emb_logo&ab_channel=Mito

# %%
# !pip install mitoinstaller

# %%
conda create -n mitoenv python=3.9

# %%
conda activate mitoenv

# %%
python -m mitoinstaller install
# Out:
#   File "<ipython-input-3-be1a71019424>", line 1
#     python -m mitoinstaller install
#               ^
# SyntaxError: invalid syntax

# %%
import mitosheet
mitosheet.sheet()

# %%
pip install --upgrade pywin32==225
